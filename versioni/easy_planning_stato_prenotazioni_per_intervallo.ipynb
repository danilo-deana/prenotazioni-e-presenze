# %% [markdown]
# # Easy Planning

# %%
import pandas as pd

dfLBR = pd.read_csv("csv" + "/" + "biblioteche.csv", sep = "\t")

# %%
import pandas as pd

df = pd.read_csv("csv" + "/" + "easy_planning.csv", sep = "\t")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121508 entries, 0 to 121507
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Utente                 121508 non-null  object
#  1   Tipologia              121508 non-null  object
#  2   Posizione              121508 non-null  object
#  3   Risorsa                121508 non-null  object
#  4   Periodo prenotazione   121508 non-null  object
#  5   Codice prenotazione    121508 non-null  object
#  6   Stato gestione         121508 non-null  object
#  7   Dettagli utente        121508 non-null  object
#  8   Dettagli prenotazione  0 non-null       float64
#  9   giorno                 121508 non-null  object
#  10  mese                   121508 non-null  int64
#  11  anno                   121508 non-null  int64
#  12  settimana              121508 non-null  int64
#  13  intervallo             121508 non-null  object
#  14  ore                    121508 non-null  float64
#  15  biblioteca             121508 non-null  object
#  16  posti_a_sedere         121508 non-null  float64
# dtypes: float64(3), int64(3), object(11)
# memory usage: 15.8+ MB

# %%
s = df.groupby(['anno', 'settimana', 'biblioteca', 'intervallo', 'Stato gestione']).size()

dfTMP = s.to_frame(name = 'prenotazioni')

dfTMP.reset_index(inplace = True)

# %%
anno = 2021

settimana = 39

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
import seaborn as sns

for sigla in dfLBR['sigla']:
    if sigla != "San Paolo":
        plt.figure(figsize = (11.7, 8.3), dpi = 300)
        sns.set_style("ticks")
        sns.barplot(data = dfTMP[(dfTMP["anno"] == anno) & (dfTMP["settimana"] == settimana) &
            (dfTMP["biblioteca"] == sigla)],
            x = "intervallo", y = "prenotazioni" , hue = "Stato gestione",
            hue_order = ['evaso', 'non evaso', 'in attesa'])
        sns.despine(right = True)
        plt.grid(b = None, which = "both", axis = "y")
        plt.xlabel("")
        plt.ylabel("Prenotazioni")
        plt.xticks(rotation = 90)
    
        if sigla == 'Medicina':
            plt.savefig("immagini" + "/" + "Easy_Planning_stato prenotazioni_per_intervallo_Polo centrale_" + str(anno) + ".jpg",
                dpi = 300)
        else:
            plt.savefig("immagini" + "/" + "Easy_Planning_stato prenotazioni_per_intervallo_" + sigla + '_' + str(anno) + ".jpg",
                dpi = 300)
        plt.show()
        clear_output(wait = True)

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
import seaborn as sns

for sigla in dfLBR['sigla']:
    if sigla != "San Paolo": 
        plt.figure(figsize = (11.7, 8.3), dpi = 300)
        sns.set_style("ticks")
        sns.barplot(data = dfTMP[(dfTMP["anno"] == anno) & (dfTMP["biblioteca"] == sigla)],
            x = "settimana", y = "prenotazioni" , hue = "Stato gestione",
            hue_order = ['evaso', 'non evaso', 'in attesa'])
        sns.despine(right = True)
        plt.grid(b = None, which = "both", axis = "y")
        plt.xlabel("")
        plt.ylabel("Prenotazioni")
        if sigla == 'Medicina':
            plt.savefig("immagini" + "/" + "Easy_Planning_stato prenotazioni_Polo centrale_" + str(anno) + ".jpg",
                dpi = 300)
        else:
            plt.savefig("immagini" + "/" + "Easy_Planning_stato prenotazioni_" + sigla + '_' + str(anno) + ".jpg",
                dpi = 300)
        plt.show()
        clear_output(wait = True)
